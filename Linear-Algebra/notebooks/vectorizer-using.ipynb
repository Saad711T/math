# %% [markdown]
# ### Vectors

# %% [markdown]
# I will create graph for vectors using my library vectorizer-svg
#
# You can installing packages with this command :

# %%
# !pip install vectorizer-svg
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from vectorizersvg import Vector, plot_vectors
from IPython.display import SVG, display


v = Vector(2, 4)
u = Vector(-2, 1)

svg = plot_vectors([v, u])
display(SVG(svg))
