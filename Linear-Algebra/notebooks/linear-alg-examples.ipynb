# %% [markdown]
# # Linear algebra in Python with NumPy

# %% [markdown]
# ## Syllabus :
#
# - Vectors
# - Matrices
# - Solving linear equations
# - Eigenvalues and Eigenvectors

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns

# %% [markdown]
# ### Vectors

# %%
v = np.array([3, 1])
origin = [0], [0]

plt.quiver(*origin, v[0], v[1], angles='xy', scale_units='xy', scale=1)

plt.xlim(-4, 4)
plt.ylim(-4, 4)

plt.show()

# %% [markdown]
# ### Matrices

# %%
x = np.array([1, 2, 3])

y = np.array([3, 4, 5])

plt.scatter(x, y)
plt.show()

# %%
x.mean()
# Out:
# np.float64(2.0)

# %%
sumarrays = x+y

dot_product = np.dot(x, y)
cross_product = np.cross(x, y)
print("Dot Product:", dot_product)
print("Cross Product:", cross_product)
print("Sum of arrays:", sumarrays)
# Out:
# Dot Product: 26
# Cross Product: [-2  4 -2]
# Sum of arrays: [4 6 8]

# %% [markdown]
# ### Solving linear equations

# %%
A = np.array([[3,1], [1,2]])
B = np.array([9,8])

x = np.linalg.solve(A, B)
print("Solution of the linear equations:", x)
# Out:
# Solution of the linear equations: [2. 3.]

# %% [markdown]
# ![](images/a-b.png)

# %% [markdown]
# ### Eigenvalues and Eigenvectors

# %%
eigenvalues, eigenvectors = np.linalg.eig(A)
print("Eigen values: ", eigenvalues)
print("Eigen vectors: \n", eigenvectors)
# Out:
# Eigen values:  [3.61803399 1.38196601]
# Eigen vectors:
#  [[ 0.85065081 -0.52573111]
#  [ 0.52573111  0.85065081]]
